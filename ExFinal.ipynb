# %% [markdown]
# <a href="https://colab.research.google.com/github/Ninkrn/BasicProg_Dataviz65/blob/main/ExFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#เชื่อม google drive 
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#เข้าไป path ใน google drive
import os
os.chdir('/content/gdrive/MyDrive/Final/')

# !pwd #เช็ค paht ที่กำลังทำงานอยู่
# Out:
# /content/gdrive/MyDrive/Final

# %%
# !ls
# Out:
# คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx	คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx

# %% [markdown]
# # คะแนนสอบปากเปล่าของกรรมการสอบ

# %% [markdown]
# ## คะแนนสอบปากเปล่าของกรรมการสอบ Day1

# %%
day1 = pd.read_excel('/content/gdrive/MyDrive/Final/คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx',sheet_name=0,skiprows=1)
day1.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0      NaN               NaN
# 1  SC 6501  08:00 – 10.00 น.
# 2      NaN               NaN
# 3      NaN               NaN
# 4      NaN               NaN
#
#                                           ชื่อเรื่อง              นักศึกษา  \
# 0                                                NaN                   NaN
# 1  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...  leaky-rust-chameleon
# 2                                                NaN    greasy-ruby-bombay
# 3                                                NaN  leaky-rust-chameleon
# 4                                                NaN    greasy-ruby-bombay
#
#      อาจารย์  กรรมการสอบ  ความชัดเจนของโจทย์การวิจัย  \
# 0  ที่ปรึกษา         NaN                          10
# 1  ดร.ธิปไตย  ผศ.วุฒิชัย                           8
# 2        NaN         NaN                           8
# 3        NaN    อ.ยุภาพร                           9
# 4        NaN         NaN                           9
#
# ...

# %%
day1_1 = day1.fillna(method='ffill')
day1_1.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0      NaN               NaN
# 1  SC 6501  08:00 – 10.00 น.
# 2  SC 6501  08:00 – 10.00 น.
# 3  SC 6501  08:00 – 10.00 น.
# 4  SC 6501  08:00 – 10.00 น.
#
#                                           ชื่อเรื่อง              นักศึกษา  \
# 0                                                NaN                   NaN
# 1  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...  leaky-rust-chameleon
# 2  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...    greasy-ruby-bombay
# 3  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...  leaky-rust-chameleon
# 4  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...    greasy-ruby-bombay
#
#      อาจารย์  กรรมการสอบ  ความชัดเจนของโจทย์การวิจัย  \
# 0  ที่ปรึกษา         NaN                          10
# 1  ดร.ธิปไตย  ผศ.วุฒิชัย                           8
# 2  ดร.ธิปไตย  ผศ.วุฒิชัย                           8
# 3  ดร.ธิปไตย    อ.ยุภาพร                           9
# 4  ดร.ธิปไตย    อ.ยุภาพร                           9
#
# ...

# %%
day1_1
# Out:
#       ห้องสอบ              เวลา  \
# 0         NaN               NaN
# 1     SC 6501  08:00 – 10.00 น.
# 2     SC 6501  08:00 – 10.00 น.
# 3     SC 6501  08:00 – 10.00 น.
# 4     SC 6501  08:00 – 10.00 น.
# 5     SC 6501  10:00 – 12.00 น.
# 6     SC 6501  10:00 – 12.00 น.
# 7     SC 6501  10:00 – 12.00 น.
# 8     SC 6501  10:00 – 12.00 น.
# 9   SC 6502\n  08:00 – 10.00 น.
# 10  SC 6502\n  08:00 – 10.00 น.
# 11  SC 6502\n  08:00 – 10.00 น.
# 12  SC 6502\n  08:00 – 10.00 น.
# 13  SC 6502\n  10:00 – 12.00 น.
# 14  SC 6502\n  10:00 – 12.00 น.
# 15  SC 6502\n  10:00 – 12.00 น.
# 16  SC 6502\n  10:00 – 12.00 น.
# 17  SC 6502\n  13:00 – 15.00 น.
# 18  SC 6502\n  13:00 – 15.00 น.
# 19  SC 6502\n  13:00 – 15.00 น.
# 20  SC 6502\n  13:00 – 15.00 น.
# 21  SC 6502\n  15:00 – 17.00 น.
# 22  SC 6502\n  15:00 – 17.00 น.
# 23  SC 6502\n  15:00 – 17.00 น.
# 24  SC 6502\n  15:00 – 17.00 น.
# 25  SC 6409\n  08:00 – 10.00 น.
# 26  SC 6409\n  08:00 – 10.00 น.
# 27  SC 6409\n  08:00 – 10.00 น.
# ...

# %%
all_aj_list = set(list(day1_1['กรรมการสอบ'].dropna()))
all_aj_list
# Out:
# {'ดร.ธนพงศ์',
#  'ดร.ธิปไตย',
#  'ดร.พลากร',
#  'ดร.วรรณพร',
#  'ดร.อุทุมพร',
#  'ผศ.วุฒิชัย',
#  'ผศ.สุกัญญา',
#  'รศ.วิชุดา',
#  'อ.ธรรณญพร',
#  'อ.ยุภาพร'}

# %% [markdown]
# ### เช็ค missing/fillna

# %%
day1_1.isnull().any()
# Out:
# ห้องสอบ                                           True
# เวลา                                              True
# ชื่อเรื่อง                                        True
# นักศึกษา                                          True
# อาจารย์                                          False
# กรรมการสอบ                                        True
# ความชัดเจนของโจทย์การวิจัย                       False
# ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง    False
# ความถูกต้องของระเบียบวิธีวิจัย                   False
# สื่อการนำเสนอ                                    False
# ความสามารถในการนำเสนอและตอบคำถาม                 False
# ความถูกต้องของเนื้อหาในเล่มรายงาน                False
# รวม                                              False
# dtype: bool

# %%
day1_1['ห้องสอบ'] = day1_1['ห้องสอบ'].fillna('0')
day1_1['เวลา'] = day1_1['เวลา'].fillna('0')
day1_1['ชื่อเรื่อง'] = day1_1['ชื่อเรื่อง'].fillna('0')
day1_1['นักศึกษา'] = day1_1['นักศึกษา'].fillna('0')
day1_1['กรรมการสอบ'] = day1_1['กรรมการสอบ'].fillna('0')

# %%
day1_1.isnull().any()
# Out:
# ห้องสอบ                                          False
# เวลา                                             False
# ชื่อเรื่อง                                       False
# นักศึกษา                                         False
# อาจารย์                                          False
# กรรมการสอบ                                       False
# ความชัดเจนของโจทย์การวิจัย                       False
# ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง    False
# ความถูกต้องของระเบียบวิธีวิจัย                   False
# สื่อการนำเสนอ                                    False
# ความสามารถในการนำเสนอและตอบคำถาม                 False
# ความถูกต้องของเนื้อหาในเล่มรายงาน                False
# รวม                                              False
# dtype: bool

# %%
day1_1.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0        0                 0
# 1  SC 6501  08:00 – 10.00 น.
# 2  SC 6501  08:00 – 10.00 น.
# 3  SC 6501  08:00 – 10.00 น.
# 4  SC 6501  08:00 – 10.00 น.
#
#                                           ชื่อเรื่อง              นักศึกษา  \
# 0                                                  0                     0
# 1  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...  leaky-rust-chameleon
# 2  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...    greasy-ruby-bombay
# 3  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...  leaky-rust-chameleon
# 4  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...    greasy-ruby-bombay
#
#      อาจารย์  กรรมการสอบ  ความชัดเจนของโจทย์การวิจัย  \
# 0  ที่ปรึกษา           0                          10
# 1  ดร.ธิปไตย  ผศ.วุฒิชัย                           8
# 2  ดร.ธิปไตย  ผศ.วุฒิชัย                           8
# 3  ดร.ธิปไตย    อ.ยุภาพร                           9
# 4  ดร.ธิปไตย    อ.ยุภาพร                           9
#
# ...

# %%
day1_1.shape
# Out:
# (55, 13)

# %% [markdown]
# ## คะแนนสอบปากเปล่าของกรรมการสอบ Day2

# %%
day2 = pd.read_excel('/content/gdrive/MyDrive/Final/คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx',sheet_name=1,skiprows=1)
day2.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0      NaN               NaN
# 1  SC 6501  08:00 – 10.00 น.
# 2      NaN               NaN
# 3      NaN               NaN
# 4      NaN               NaN
#
#                                           ชื่อเรื่อง  \
# 0                                                NaN
# 1  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                      นักศึกษา    อาจารย์ กรรมการสอบ  \
# 0                         NaN  ที่ปรึกษา        NaN
# 1            tasty-myrtle-ant  รศ.วิชุดา  ดร.ธนพงศ์
# 2  skanky-burgundy-kingfisher        NaN        NaN
# 3            tasty-myrtle-ant        NaN   ดร.พลากร
# 4  skanky-burgundy-kingfisher        NaN        NaN
#
#    ความชัดเจนของโจทย์การวิจัย  ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง  \
# ...

# %%
day2_2 = day2.fillna(method='ffill')
day2_2.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0      NaN               NaN
# 1  SC 6501  08:00 – 10.00 น.
# 2  SC 6501  08:00 – 10.00 น.
# 3  SC 6501  08:00 – 10.00 น.
# 4  SC 6501  08:00 – 10.00 น.
#
#                                           ชื่อเรื่อง  \
# 0                                                NaN
# 1  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
# 2  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
# 3  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
# 4  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
#
#                      นักศึกษา    อาจารย์ กรรมการสอบ  \
# 0                         NaN  ที่ปรึกษา        NaN
# 1            tasty-myrtle-ant  รศ.วิชุดา  ดร.ธนพงศ์
# 2  skanky-burgundy-kingfisher  รศ.วิชุดา  ดร.ธนพงศ์
# 3            tasty-myrtle-ant  รศ.วิชุดา   ดร.พลากร
# 4  skanky-burgundy-kingfisher  รศ.วิชุดา   ดร.พลากร
#
#    ความชัดเจนของโจทย์การวิจัย  ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง  \
# ...

# %%
day2_2
# Out:
#       ห้องสอบ              เวลา  \
# 0         NaN               NaN
# 1     SC 6501  08:00 – 10.00 น.
# 2     SC 6501  08:00 – 10.00 น.
# 3     SC 6501  08:00 – 10.00 น.
# 4     SC 6501  08:00 – 10.00 น.
# 5     SC 6501  10:00 – 12.00 น.
# 6     SC 6501  10:00 – 12.00 น.
# 7     SC 6501  10:00 – 12.00 น.
# 8     SC 6501  10:00 – 12.00 น.
# 9     SC 6501  13:00 – 15.00 น.
# 10    SC 6501  13:00 – 15.00 น.
# 11    SC 6501  13:00 – 15.00 น.
# 12    SC 6501  13:00 – 15.00 น.
# 13    SC 6501  15:00 – 17.00 น.
# 14    SC 6501  15:00 – 17.00 น.
# 15    SC 6501  15:00 – 17.00 น.
# 16    SC 6501  15:00 – 17.00 น.
# 17  SC 6502\n  08:00 – 10.00 น.
# 18  SC 6502\n  08:00 – 10.00 น.
# 19  SC 6502\n  08:00 – 10.00 น.
# 20  SC 6502\n  08:00 – 10.00 น.
# 21  SC 6502\n  10:00 – 12.00 น.
# 22  SC 6502\n  10:00 – 12.00 น.
# 23  SC 6502\n  13:00 – 15.00 น.
# 24  SC 6502\n  13:00 – 15.00 น.
# 25  SC 6502\n  13:00 – 15.00 น.
# 26  SC 6502\n  13:00 – 15.00 น.
# 27  SC 6502\n  15:00 – 17.00 น.
# ...

# %%
all_aj_list2 = set(list(day2_2['กรรมการสอบ'].dropna()))
all_aj_list2
# Out:
# {'ดร.ธนพงศ์',
#  'ดร.ธิปไตย',
#  'ดร.พลากร',
#  'ดร.อุทุมพร',
#  'ผศ.วุฒิชัย',
#  'ผศ.สุกัญญา',
#  'รศ.ธิดาเดียว',
#  'รศ.วิชุดา',
#  'รศ.สุพรรณี',
#  'อ.ธรรณญพร',
#  'อ.ยุภาพร'}

# %% [markdown]
# ### เช็ค missing

# %%
day2_2.isnull().any()
# Out:
# ห้องสอบ                                           True
# เวลา                                              True
# ชื่อเรื่อง                                        True
# นักศึกษา                                          True
# อาจารย์                                          False
# กรรมการสอบ                                        True
# ความชัดเจนของโจทย์การวิจัย                       False
# ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง    False
# ความถูกต้องของระเบียบวิธีวิจัย                   False
# สื่อการนำเสนอ                                    False
# ความสามารถในการนำเสนอและตอบคำถาม                 False
# ความถูกต้องของเนื้อหาในเล่มรายงาน                False
# รวม                                              False
# dtype: bool

# %%
day2_2['ห้องสอบ'] = day2_2['ห้องสอบ'].fillna('0')
day2_2['เวลา'] = day2_2['เวลา'].fillna('0')
day2_2['ชื่อเรื่อง'] = day2_2['ชื่อเรื่อง'].fillna('0')
day2_2['นักศึกษา'] = day2_2['นักศึกษา'].fillna('0')
day2_2['กรรมการสอบ'] = day2_2['กรรมการสอบ'].fillna('0')

# %%
day2_2.isnull().any()
# Out:
# ห้องสอบ                                          False
# เวลา                                             False
# ชื่อเรื่อง                                       False
# นักศึกษา                                         False
# อาจารย์                                          False
# กรรมการสอบ                                       False
# ความชัดเจนของโจทย์การวิจัย                       False
# ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง    False
# ความถูกต้องของระเบียบวิธีวิจัย                   False
# สื่อการนำเสนอ                                    False
# ความสามารถในการนำเสนอและตอบคำถาม                 False
# ความถูกต้องของเนื้อหาในเล่มรายงาน                False
# รวม                                              False
# dtype: bool

# %%
day2_2.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0        0                 0
# 1  SC 6501  08:00 – 10.00 น.
# 2  SC 6501  08:00 – 10.00 น.
# 3  SC 6501  08:00 – 10.00 น.
# 4  SC 6501  08:00 – 10.00 น.
#
#                                           ชื่อเรื่อง  \
# 0                                                  0
# 1  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
# 2  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
# 3  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
# 4  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
#
#                      นักศึกษา    อาจารย์ กรรมการสอบ  \
# 0                           0  ที่ปรึกษา          0
# 1            tasty-myrtle-ant  รศ.วิชุดา  ดร.ธนพงศ์
# 2  skanky-burgundy-kingfisher  รศ.วิชุดา  ดร.ธนพงศ์
# 3            tasty-myrtle-ant  รศ.วิชุดา   ดร.พลากร
# 4  skanky-burgundy-kingfisher  รศ.วิชุดา   ดร.พลากร
#
#    ความชัดเจนของโจทย์การวิจัย  ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง  \
# ...

# %%
day2_2.shape
# Out:
# (53, 13)

# %% [markdown]
# ## คะแนนสอบปากเปล่าของกรรมการสอบ Day3

# %%
day3 = pd.read_excel('/content/gdrive/MyDrive/Final/คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx',sheet_name=2,skiprows=1)
day3.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0      NaN               NaN
# 1  SC 6501  08:00 – 10.00 น.
# 2      NaN               NaN
# 3      NaN  10:00 – 12.00 น.
# 4      NaN               NaN
#
#                                           ชื่อเรื่อง                นักศึกษา  \
# 0                                                NaN                     NaN
# 1  29.พฤติกรรมการใช้แอพพลิเคชั่นในการเรียนออนไลน์...      frumpy-gamboge-emu
# 2                                                NaN                     NaN
# 3  30.ความคิดเห็นของนักศึกษาเกี่ยวกับคุณภาพสารสนเ...  ugly-harlequin-octopus
# 4                                                NaN   craggy-cream-paradise
#
#      อาจารย์  กรรมการสอบ  ความชัดเจนของโจทย์การวิจัย  \
# 0  ที่ปรึกษา         NaN                        10.0
# 1  รศ.วิชุดา   ดร.ธิปไตย                         8.0
# 2        NaN  รศ.สุพรรณี                         6.0
# 3  รศ.วิชุดา   ดร.ธิปไตย                         9.0
# ...

# %%
day3_3 = day3.fillna(method='ffill')
day3_3.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0      NaN               NaN
# 1  SC 6501  08:00 – 10.00 น.
# 2  SC 6501  08:00 – 10.00 น.
# 3  SC 6501  10:00 – 12.00 น.
# 4  SC 6501  10:00 – 12.00 น.
#
#                                           ชื่อเรื่อง                นักศึกษา  \
# 0                                                NaN                     NaN
# 1  29.พฤติกรรมการใช้แอพพลิเคชั่นในการเรียนออนไลน์...      frumpy-gamboge-emu
# 2  29.พฤติกรรมการใช้แอพพลิเคชั่นในการเรียนออนไลน์...      frumpy-gamboge-emu
# 3  30.ความคิดเห็นของนักศึกษาเกี่ยวกับคุณภาพสารสนเ...  ugly-harlequin-octopus
# 4  30.ความคิดเห็นของนักศึกษาเกี่ยวกับคุณภาพสารสนเ...   craggy-cream-paradise
#
#      อาจารย์  กรรมการสอบ  ความชัดเจนของโจทย์การวิจัย  \
# 0  ที่ปรึกษา         NaN                        10.0
# 1  รศ.วิชุดา   ดร.ธิปไตย                         8.0
# 2  รศ.วิชุดา  รศ.สุพรรณี                         6.0
# 3  รศ.วิชุดา   ดร.ธิปไตย                         9.0
# ...

# %%
day3_3
# Out:
#       ห้องสอบ              เวลา  \
# 0         NaN               NaN
# 1     SC 6501  08:00 – 10.00 น.
# 2     SC 6501  08:00 – 10.00 น.
# 3     SC 6501  10:00 – 12.00 น.
# 4     SC 6501  10:00 – 12.00 น.
# 5     SC 6501  10:00 – 12.00 น.
# 6     SC 6501  10:00 – 12.00 น.
# 7     SC 6501  13:00 – 15.00 น.
# 8     SC 6501  13:00 – 15.00 น.
# 9     SC 6501  13:00 – 15.00 น.
# 10    SC 6501  13:00 – 15.00 น.
# 11    SC 6501  15:00 – 17.00 น.
# 12    SC 6501  15:00 – 17.00 น.
# 13    SC 6501  15:00 – 17.00 น.
# 14    SC 6501  15:00 – 17.00 น.
# 15    SC 6502  10:00 – 12.00 น.
# 16    SC 6502  10:00 – 12.00 น.
# 17    SC 6502  10:00 – 12.00 น.
# 18    SC 6502  10:00 – 12.00 น.
# 19    SC 6502  13:00 – 15.00 น.
# 20    SC 6502  13:00 – 15.00 น.
# 21    SC 6502  13:00 – 15.00 น.
# 22    SC 6502  13:00 – 15.00 น.
# 23    SC 6502  15:00 – 17.00 น.
# 24    SC 6502  15:00 – 17.00 น.
# 25    SC 6502  15:00 – 17.00 น.
# 26    SC 6502  15:00 – 17.00 น.
# 27  SC 6409\n  08:00 – 10.00 น.
# ...

# %% [markdown]
# ### เช็ค missing

# %%
day3_3.isnull().any()
# Out:
# ห้องสอบ                                           True
# เวลา                                              True
# ชื่อเรื่อง                                        True
# นักศึกษา                                          True
# อาจารย์                                          False
# กรรมการสอบ                                        True
# ความชัดเจนของโจทย์การวิจัย                       False
# ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง    False
# ความถูกต้องของระเบียบวิธีวิจัย                   False
# สื่อการนำเสนอ                                    False
# ความสามารถในการนำเสนอและตอบคำถาม                 False
# ความถูกต้องของเนื้อหาในเล่มรายงาน                False
# รวม                                              False
# dtype: bool

# %%
day3_3['ห้องสอบ'] = day3_3['ห้องสอบ'].fillna('0')
day3_3['เวลา'] = day3_3['เวลา'].fillna('0')
day3_3['ชื่อเรื่อง'] = day3_3['ชื่อเรื่อง'].fillna('0')
day3_3['นักศึกษา'] = day3_3['นักศึกษา'].fillna('0')
day3_3['กรรมการสอบ'] = day3_3['กรรมการสอบ'].fillna('0')

# %%
day3_3.isnull().any()
# Out:
# ห้องสอบ                                          False
# เวลา                                             False
# ชื่อเรื่อง                                       False
# นักศึกษา                                         False
# อาจารย์                                          False
# กรรมการสอบ                                       False
# ความชัดเจนของโจทย์การวิจัย                       False
# ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง    False
# ความถูกต้องของระเบียบวิธีวิจัย                   False
# สื่อการนำเสนอ                                    False
# ความสามารถในการนำเสนอและตอบคำถาม                 False
# ความถูกต้องของเนื้อหาในเล่มรายงาน                False
# รวม                                              False
# dtype: bool

# %%
day3_3.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0        0                 0
# 1  SC 6501  08:00 – 10.00 น.
# 2  SC 6501  08:00 – 10.00 น.
# 3  SC 6501  10:00 – 12.00 น.
# 4  SC 6501  10:00 – 12.00 น.
#
#                                           ชื่อเรื่อง                นักศึกษา  \
# 0                                                  0                       0
# 1  29.พฤติกรรมการใช้แอพพลิเคชั่นในการเรียนออนไลน์...      frumpy-gamboge-emu
# 2  29.พฤติกรรมการใช้แอพพลิเคชั่นในการเรียนออนไลน์...      frumpy-gamboge-emu
# 3  30.ความคิดเห็นของนักศึกษาเกี่ยวกับคุณภาพสารสนเ...  ugly-harlequin-octopus
# 4  30.ความคิดเห็นของนักศึกษาเกี่ยวกับคุณภาพสารสนเ...   craggy-cream-paradise
#
#      อาจารย์  กรรมการสอบ  ความชัดเจนของโจทย์การวิจัย  \
# 0  ที่ปรึกษา           0                        10.0
# 1  รศ.วิชุดา   ดร.ธิปไตย                         8.0
# 2  รศ.วิชุดา  รศ.สุพรรณี                         6.0
# 3  รศ.วิชุดา   ดร.ธิปไตย                         9.0
# ...

# %%
day3_3.shape
# Out:
# (55, 13)

# %% [markdown]
# # ต่อตารางคะแนนสอบปากเปล่าของกรรมการสสอบ Day1-3

# %% [markdown]
# ## ต่อตารางคะแนนสอบปากเปล่าของกรรมการสสอบ Day1 กับ Day2

# %%
day1_1.columns
# Out:
# Index(['ห้องสอบ', 'เวลา', 'ชื่อเรื่อง', 'นักศึกษา', 'อาจารย์', 'กรรมการสอบ',
#        'ความชัดเจนของโจทย์การวิจัย',
#        'ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง',
#        'ความถูกต้องของระเบียบวิธีวิจัย', 'สื่อการนำเสนอ',
#        'ความสามารถในการนำเสนอและตอบคำถาม', 'ความถูกต้องของเนื้อหาในเล่มรายงาน',
#        'รวม'],
#       dtype='object')

# %%
day2_2.columns
# Out:
# Index(['ห้องสอบ', 'เวลา', 'ชื่อเรื่อง', 'นักศึกษา', 'อาจารย์', 'กรรมการสอบ',
#        'ความชัดเจนของโจทย์การวิจัย',
#        'ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง',
#        'ความถูกต้องของระเบียบวิธีวิจัย', 'สื่อการนำเสนอ',
#        'ความสามารถในการนำเสนอและตอบคำถาม', 'ความถูกต้องของเนื้อหาในเล่มรายงาน',
#        'รวม'],
#       dtype='object')

# %%
day12 = pd.concat([day1_1,day2_2])

# %%
day12.shape
# Out:
# (108, 13)

# %%
day12
# Out:
#     ห้องสอบ              เวลา  \
# 0         0                 0
# 1   SC 6501  08:00 – 10.00 น.
# 2   SC 6501  08:00 – 10.00 น.
# 3   SC 6501  08:00 – 10.00 น.
# 4   SC 6501  08:00 – 10.00 น.
# ..      ...               ...
# 48  SC 6410  13:00 – 15.00 น.
# 49  SC 6410  15:00 – 17.00 น.
# 50  SC 6410  15:00 – 17.00 น.
# 51  SC 6410  15:00 – 17.00 น.
# 52  SC 6410  15:00 – 17.00 น.
#
#                                            ชื่อเรื่อง               นักศึกษา  \
# 0                                                   0                      0
# 1   1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...   leaky-rust-chameleon
# 2   1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...     greasy-ruby-bombay
# 3   1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...   leaky-rust-chameleon
# 4   1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...     greasy-ruby-bombay
# ..                                                ...                    ...
# ...

# %%
day12.isnull().any()
# Out:
# ห้องสอบ                                          False
# เวลา                                             False
# ชื่อเรื่อง                                       False
# นักศึกษา                                         False
# อาจารย์                                          False
# กรรมการสอบ                                       False
# ความชัดเจนของโจทย์การวิจัย                       False
# ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง    False
# ความถูกต้องของระเบียบวิธีวิจัย                   False
# สื่อการนำเสนอ                                    False
# ความสามารถในการนำเสนอและตอบคำถาม                 False
# ความถูกต้องของเนื้อหาในเล่มรายงาน                False
# รวม                                              False
# dtype: bool

# %% [markdown]
# ## ต่อตารางคะแนนสอบปากเปล่าของกรรมการสสอบ Day12 กับ Day3

# %%
day12.columns
# Out:
# Index(['ห้องสอบ', 'เวลา', 'ชื่อเรื่อง', 'นักศึกษา', 'อาจารย์', 'กรรมการสอบ',
#        'ความชัดเจนของโจทย์การวิจัย',
#        'ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง',
#        'ความถูกต้องของระเบียบวิธีวิจัย', 'สื่อการนำเสนอ',
#        'ความสามารถในการนำเสนอและตอบคำถาม', 'ความถูกต้องของเนื้อหาในเล่มรายงาน',
#        'รวม'],
#       dtype='object')

# %%
day3_3.columns
# Out:
# Index(['ห้องสอบ', 'เวลา', 'ชื่อเรื่อง', 'นักศึกษา', 'อาจารย์', 'กรรมการสอบ',
#        'ความชัดเจนของโจทย์การวิจัย',
#        'ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง',
#        'ความถูกต้องของระเบียบวิธีวิจัย', 'สื่อการนำเสนอ',
#        'ความสามารถในการนำเสนอและตอบคำถาม', 'ความถูกต้องของเนื้อหาในเล่มรายงาน',
#        'รวม'],
#       dtype='object')

# %%
day123 = pd.concat([day12,day3_3])

# %%
day123.shape
# Out:
# (163, 13)

# %%
day123
# Out:
#     ห้องสอบ              เวลา  \
# 0         0                 0
# 1   SC 6501  08:00 – 10.00 น.
# 2   SC 6501  08:00 – 10.00 น.
# 3   SC 6501  08:00 – 10.00 น.
# 4   SC 6501  08:00 – 10.00 น.
# ..      ...               ...
# 50  SC 6410  10:00 – 12.00 น.
# 51  SC 6410  13:00 – 15.00 น.
# 52  SC 6410  13:00 – 15.00 น.
# 53  SC 6410  13:00 – 15.00 น.
# 54  SC 6410  13:00 – 15.00 น.
#
#                                            ชื่อเรื่อง  \
# 0                                                   0
# 1   1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...
# 2   1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...
# 3   1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...
# 4   1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...
# ..                                                ...
# 50  41.ตัวแบบการพยากรณ์ปริมาณการส่งออกข้าวรายเดือน...
# 51  42.การพัฒนาระบบสารสนเทศการสั่งอาหารร้านปลาวาฬใ...
# 52  42.การพัฒนาระบบสารสนเทศการสั่งอาหารร้านปลาวาฬใ...
# ...

# %% [markdown]
# # คะแนนอาจารย์ที่ปรึกษา

# %% [markdown]
# # คะแนนอาจารย์ที่ปรึกษา ดร.ธิปไตย

# %%
advisor1 = pd.read_excel('/content/gdrive/MyDrive/Final/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ดร.ธิปไตย',skiprows=1)
advisor1.head()
# Out:
#              Unnamed: 0  \
# 0                   NaN
# 1  leaky-rust-chameleon
# 2    greasy-ruby-bombay
# 3   wiggy-silver-drever
# 4       stinky-red-chow
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor1
# Out:
#              Unnamed: 0  \
# 0                   NaN
# 1  leaky-rust-chameleon
# 2    greasy-ruby-bombay
# 3   wiggy-silver-drever
# 4       stinky-red-chow
# 5  bumpy-indigo-dolphin
# 6   randy-rust-lionfish
# 7    flaky-sepia-setter
# 8    pasty-tomato-okapi
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
# 5                                                  5
# 6                                                  4
# 7                                                  5
# 8                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# ...

# %%
advisor1 = advisor.fillna(method='ffill')
advisor1.head()
# Out:
#                  Unnamed: 0  \
# 0                       NaN
# 1       jumpy-apricot-frise
# 2  boozy-thistle-wildebeest
# 3      hasty-magnolia-devil
# 4   chummy-goldenrod-walrus
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %% [markdown]
# ### เช็ค missing/fillna

# %%
advisor2.isnull().any()
# Out:
# Unnamed: 0                                                                                    True
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %%
advisor2.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor2.head(3)
# Out:
#                   ชื่อ-สกุล  \
# 0                       NaN
# 1       jumpy-apricot-frise
# 2  boozy-thistle-wildebeest
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                 10
# 2                                                  9
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                      5
# ...

# %%
advisor2['ชื่อ-สกุล'] = advisor2['ชื่อ-สกุล'].fillna('0')
advisor2['ชื่อเรื่อง'] = advisor2['ชื่อเรื่อง'].fillna('0')

# %%
advisor2
# Out:
#                   ชื่อ-สกุล  \
# 0                         0
# 1       jumpy-apricot-frise
# 2  boozy-thistle-wildebeest
# 3      hasty-magnolia-devil
# 4   chummy-goldenrod-walrus
# 5        randy-gamboge-blue
# 6   flimsy-lemon-budgerigar
# 7     skimpy-magenta-bombay
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
# 5                                                  4
# 6                                                  4
# 7                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# ...

# %%
advisor2.isnull().any()
# Out:
# ชื่อ-สกุล                                                                                    False
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %% [markdown]
# # คะแนนอาจารย์ที่ปรึกษา รศ.ธิดาเดียว

# %%
advisor3 = pd.read_excel('/content/gdrive/MyDrive/Final/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='รศ.ธิดาเดียว',skiprows=1)
advisor3.head()
# Out:
#                   Unnamed: 0  \
# 0                        NaN
# 1          paltry-plum-saola
# 2        cloudy-wheat-bobcat
# 3  gloppy-persimmon-flamingo
# 4       sleepy-gamboge-zebra
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor3
# Out:
#                   Unnamed: 0  \
# 0                        NaN
# 1          paltry-plum-saola
# 2        cloudy-wheat-bobcat
# 3  gloppy-persimmon-flamingo
# 4       sleepy-gamboge-zebra
# 5         sickly-grey-dugong
# 6    slaphappy-silver-monkey
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
# 5                                                  5
# 6                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# ...

# %%
advisor3 = advisor.fillna(method='ffill')
advisor3.head()
# Out:
#                  Unnamed: 0  \
# 0                       NaN
# 1       jumpy-apricot-frise
# 2  boozy-thistle-wildebeest
# 3      hasty-magnolia-devil
# 4   chummy-goldenrod-walrus
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %% [markdown]
# ### เช็ค missing/fillna

# %%
advisor3.isnull().any()
# Out:
# Unnamed: 0                                                                                    True
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %%
advisor3.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor3.head(3)
# Out:
#                   ชื่อ-สกุล  \
# 0                       NaN
# 1       jumpy-apricot-frise
# 2  boozy-thistle-wildebeest
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                 10
# 2                                                  9
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                      5
# ...

# %%
advisor3['ชื่อ-สกุล'] = advisor3['ชื่อ-สกุล'].fillna('0')
advisor3['ชื่อเรื่อง'] = advisor3['ชื่อเรื่อง'].fillna('0')

# %%
advisor3
# Out:
#                   ชื่อ-สกุล  \
# 0                         0
# 1       jumpy-apricot-frise
# 2  boozy-thistle-wildebeest
# 3      hasty-magnolia-devil
# 4   chummy-goldenrod-walrus
# 5        randy-gamboge-blue
# 6   flimsy-lemon-budgerigar
# 7     skimpy-magenta-bombay
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
# 5                                                  4
# 6                                                  4
# 7                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# ...

# %%
advisor3.isnull().any()
# Out:
# ชื่อ-สกุล                                                                                    False
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %% [markdown]
# # คะแนนอาจารย์ที่ปรึกษา ผศ.สุกัญญา

# %%
advisor4 = pd.read_excel('/content/gdrive/MyDrive/Final/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ผศ.สุกัญญา',skiprows=1)
advisor4.head()
# Out:
#                 Unnamed: 0  \
# 0                      NaN
# 1         whiny-pear-otter
# 2    craggy-cream-reindeer
# 3       cloudy-myrtle-kudu
# 4  lovely-asparagus-urchin
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor4
# Out:
#                  Unnamed: 0  \
# 0                       NaN
# 1          whiny-pear-otter
# 2     craggy-cream-reindeer
# 3        cloudy-myrtle-kudu
# 4   lovely-asparagus-urchin
# 5   clammy-zucchini-chicken
# 6  greasy-tangerine-moorhen
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
# 5                                                  5
# 6                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# ...

# %%
advisor4 = advisor.fillna(method='ffill')
advisor4.head()
# Out:
#                  Unnamed: 0  \
# 0                       NaN
# 1       jumpy-apricot-frise
# 2  boozy-thistle-wildebeest
# 3      hasty-magnolia-devil
# 4   chummy-goldenrod-walrus
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %% [markdown]
# ### เช็ค missing/fillna

# %%
advisor4.isnull().any()
# Out:
# Unnamed: 0                                                                                    True
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %%
advisor4.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor4.head(3)
# Out:
#                   ชื่อ-สกุล  \
# 0                       NaN
# 1       jumpy-apricot-frise
# 2  boozy-thistle-wildebeest
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                 10
# 2                                                  9
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                      5
# ...

# %%
advisor4['ชื่อ-สกุล'] = advisor4['ชื่อ-สกุล'].fillna('0')
advisor4['ชื่อเรื่อง'] = advisor4['ชื่อเรื่อง'].fillna('0')

# %%
advisor4
# Out:
#                   ชื่อ-สกุล  \
# 0                         0
# 1       jumpy-apricot-frise
# 2  boozy-thistle-wildebeest
# 3      hasty-magnolia-devil
# 4   chummy-goldenrod-walrus
# 5        randy-gamboge-blue
# 6   flimsy-lemon-budgerigar
# 7     skimpy-magenta-bombay
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
# 5                                                  4
# 6                                                  4
# 7                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# ...

# %%
advisor4.isnull().any()
# Out:
# ชื่อ-สกุล                                                                                    False
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %% [markdown]
# # คะแนนอาจารย์ที่ปรึกษา ผศ.วุฒิชัย
